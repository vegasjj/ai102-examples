# %%
# %pip install requests
# %pip install python-dotenv
# Out:
# Requirement already satisfied: requests in ./.translator-simple/lib/python3.12/site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.translator-simple/lib/python3.12/site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.translator-simple/lib/python3.12/site-packages (from requests) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.translator-simple/lib/python3.12/site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.translator-simple/lib/python3.12/site-packages (from requests) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in ./.translator-simple/lib/python3.12/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests, uuid, json, os
from dotenv import load_dotenv

# %%
# Add your key and endpoint
load_dotenv()
key = os.getenv("key")
endpoint = "https://api.cognitive.microsofttranslator.com"
location = "eastus"

# %%
print(key)

# %%
path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0', 
    'from': 'en', 
    'to': ['fr', 'it']
}

headers = {
    'Ocp-Apim-Subscription-Key': key,
    # location required if you're using a multi-service or regional (not global) resource.
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'We are wasting time here, let us ho!'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
